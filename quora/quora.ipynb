# %% [markdown]
# learn code：
# https://www.kaggle.com/anokas/quora-question-pairs/data-analysis-xgboost-starter-0-35460-lb
#
# data:
# /Users/galphen/Desktop/quora
#
# project description:
# https://www.kaggle.com/c/quora-question-pairs/kernels

# %% [markdown]
# install seaborn
# https://anaconda.org/anaconda/seaborn
#
# http://www.cnblogs.com/kylinlin/p/5236601.html
# Seaborn其实是在matplotlib的基础上进行了更高级的API封装，从而使得作图更加容易，在大多数情况下使用seaborn就能做出很具有吸引力的图，而使用matplotlib就能制作具有更多特色的图。应该把Seaborn视为matplotlib的补充，而不是替代物。

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import gc
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train = pd.read_csv('/Users/galphen/Desktop/quora/train.csv')
df_train.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
print('Total number of question pairs for training: {}'.format(len(df_train)))
print('Duplicate pairs: {}%'.format(round(df_train['is_duplicate'].mean()*100, 2)))
qids = pd.Series(df_train['qid1'].tolist() + df_train['qid2'].tolist())
print('Total number of questions in the training data: {}'.format(len(
    np.unique(qids))))
print('Number of questions that appear multiple times: {}'.format(np.sum(qids.value_counts() > 1)))

plt.figure(figsize=(12, 5))
plt.hist(qids.value_counts(), bins=50)
plt.yscale('log', nonposy='clip')
plt.title('Log-Histogram of question appearance counts')
plt.xlabel('Number of occurences of question')
plt.ylabel('Number of questions')
print()
# Out:
# Total number of question pairs for training: 404290
# Duplicate pairs: 36.92%
# Total number of questions in the training data: 537933
# Number of questions that appear multiple times: 111780
# ()

# %%
from sklearn.metrics import log_loss

p = df_train['is_duplicate'].mean() # Our predicted probability
print('Predicted score:', log_loss(df_train['is_duplicate'], np.zeros_like(df_train['is_duplicate']) + p))

df_test = pd.read_csv('/Users/galphen/Desktop/quora/test.csv')
sub = pd.DataFrame({'test_id': df_test['test_id'], 'is_duplicate': p})
sub.to_csv('naive_submission.csv', index=False)
sub.head()
# Out:
# ('Predicted score:', 0.65852738398443544)
#    is_duplicate  test_id
# 0      0.369198        0
# 1      0.369198        1
# 2      0.369198        2
# 3      0.369198        3
# 4      0.369198        4

# %%
df_test = pd.read_csv('/Users/galphen/Desktop/quora/test.csv')
df_test.head()
# Out:
#    test_id                                          question1  \
# 0        0  How does the Surface Pro himself 4 compare wit...
# 1        1  Should I have a hair transplant at age 24? How...
# 2        2  What but is the best way to send money from Ch...
# 3        3                        Which food not emulsifiers?
# 4        4                   How "aberystwyth" start reading?
#
#                                            question2
# 0  Why did Microsoft choose core m3 and not core ...
# 1        How much cost does hair transplant require?
# 2                      What you send money to China?
# 3                                  What foods fibre?
# 4                     How their can I start reading?

# %%
print('Total number of question pairs for testing: {}'.format(len(df_test)))
# Out:
# Total number of question pairs for testing: 2345796

# %%
train_qs = pd.Series(df_train['question1'].tolist() + df_train['question2'].tolist()).astype(str)
test_qs = pd.Series(df_test['question1'].tolist() + df_test['question2'].tolist()).astype(str)

dist_train = train_qs.apply(len)
dist_test = test_qs.apply(len)
# plt.figure(figsize=(15, 10))
# plt.hist(dist_train, bins=200, range=[0, 200], color=pal[2], normed=True, label='train')
# plt.hist(dist_test, bins=200, range=[0, 200], color=pal[1], normed=True, alpha=0.5, label='test')
# plt.title('Normalised histogram of character count in questions', fontsize=15)
# plt.legend()
# plt.xlabel('Number of characters', fontsize=15)
# plt.ylabel('Probability', fontsize=15)

print('mean-train {:.2f} std-train {:.2f} mean-test {:.2f} std-test {:.2f} max-train {:.2f} max-test {:.2f}'.format(dist_train.mean(), 
                          dist_train.std(), dist_test.mean(), dist_test.std(), dist_train.max(), dist_test.max()))
# Out:
# mean-train 59.86 std-train 31.99 mean-test 60.11 std-test 31.66 max-train 1169.00 max-test 1176.00

# %%
dist_train = train_qs.apply(lambda x: len(x.split(' ')))
dist_test = test_qs.apply(lambda x: len(x.split(' ')))

# plt.figure(figsize=(15, 10))
# plt.hist(dist_train, bins=50, range=[0, 50], color=pal[2], normed=True, label='train')
# plt.hist(dist_test, bins=50, range=[0, 50], color=pal[1], normed=True, alpha=0.5, label='test')
# plt.title('Normalised histogram of word count in questions', fontsize=15)
# plt.legend()
# plt.xlabel('Number of words', fontsize=15)
# plt.ylabel('Probability', fontsize=15)

print('mean-train {:.2f} std-train {:.2f} mean-test {:.2f} std-test {:.2f} max-train {:.2f} max-test {:.2f}'.format(dist_train.mean(), 
                          dist_train.std(), dist_test.mean(), dist_test.std(), dist_train.max(), dist_test.max()))
# Out:
# mean-train 11.06 std-train 5.89 mean-test 11.02 std-test 5.84 max-train 237.00 max-test 238.00

# %% [markdown]
# wordcloud install
# https://github.com/amueller/word_cloud
#
# install issue
# https://github.com/amueller/word_cloud/issues/200

# %%
from wordcloud import WordCloud
cloud = WordCloud(width=1440, height=1080).generate(" ".join(train_qs.astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 1439.5, 1079.5, -0.5)

# %%
qmarks = np.mean(train_qs.apply(lambda x: '?' in x))
math = np.mean(train_qs.apply(lambda x: '[math]' in x))
fullstop = np.mean(train_qs.apply(lambda x: '.' in x))
capital_first = np.mean(train_qs.apply(lambda x: x[0].isupper()))
capitals = np.mean(train_qs.apply(lambda x: max([y.isupper() for y in x])))
numbers = np.mean(train_qs.apply(lambda x: max([y.isdigit() for y in x])))

print('Questions with question marks: {:.2f}%'.format(qmarks * 100))
print('Questions with [math] tags: {:.2f}%'.format(math * 100))
print('Questions with full stops: {:.2f}%'.format(fullstop * 100))
print('Questions with capitalised first letters: {:.2f}%'.format(capital_first * 100))
print('Questions with capital letters: {:.2f}%'.format(capitals * 100))
print('Questions with numbers: {:.2f}%'.format(numbers * 100))
# Out:
# Questions with question marks: 99.87%
# Questions with [math] tags: 0.12%
# Questions with full stops: 6.31%
# Questions with capitalised first letters: 99.81%
# Questions with capital letters: 99.95%
# Questions with numbers: 11.83%

# %% [markdown]
# stopwords install
# https://www.douban.com/note/534906136/

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords

stops = set(stopwords.words("english"))

def word_match_share(row):
    q1words = {}
    q2words = {}
    for word in str(row['question1']).lower().split():
        if word not in stops:
            q1words[word] = 1
    for word in str(row['question2']).lower().split():
        if word not in stops:
            q2words[word] = 1
    if len(q1words) == 0 or len(q2words) == 0:
        # The computer-generated chaff includes a few questions that are nothing but stopwords
        return 0
    shared_words_in_q1 = [w for w in q1words.keys() if w in q2words]
    shared_words_in_q2 = [w for w in q2words.keys() if w in q1words]
    R = (len(shared_words_in_q1) + len(shared_words_in_q2))/(len(q1words) + len(q2words))
    return R

plt.figure(figsize=(15, 5))
train_word_match = df_train.apply(word_match_share, axis=1, raw=True)
plt.hist(train_word_match[df_train['is_duplicate'] == 0], bins=20, normed=True, label='Not Duplicate')
plt.hist(train_word_match[df_train['is_duplicate'] == 1], bins=20, normed=True, alpha=0.7, label='Duplicate')
plt.legend()
plt.title('Label distribution over word_match_share', fontsize=15)
plt.xlabel('word_match_share', fontsize=15)

# %%
from collections import Counter

# If a word appears only once, we ignore it completely (likely a typo)
# Epsilon defines a smoothing constant, which makes the effect of extremely rare words smaller
def get_weight(count, eps=10000, min_count=2):
    if count < min_count:
        return 0
    else:
        return 1 / (count + eps)

eps = 5000 
words = (" ".join(train_qs)).lower().split()
counts = Counter(words)
weights = {word: get_weight(count) for word, count in counts.items()}

# %%
print('Most common words and weights: \n')
print(sorted(weights.items(), key=lambda x: x[1] if x[1] > 0 else 9999)[:10])
print('\nLeast common words and weights: ')
(sorted(weights.items(), key=lambda x: x[1], reverse=True)[:10])
# Out:
# Most common words and weights:
#
# [('considered,', 0), ('considered.', 0), ('pieces/rest', 0), ('(nfl)', 0), ('daiict', 0), ('sunflowers?', 0), ('throwaround', 0), ('telepat.io?', 0), ('considered?', 0), ('woods', 0)]
#
# Least common words and weights:
# [('considered,', 0),
#  ('considered.', 0),
#  ('pieces/rest', 0),
#  ('(nfl)', 0),
#  ('daiict', 0),
#  ('sunflowers?', 0),
#  ('throwaround', 0),
#  ('telepat.io?', 0),
#  ('considered?', 0),
#  ('woods', 0)]

# %%
def tfidf_word_match_share(row):
    q1words = {}
    q2words = {}
    for word in str(row['question1']).lower().split():
        if word not in stops:
            q1words[word] = 1
    for word in str(row['question2']).lower().split():
        if word not in stops:
            q2words[word] = 1
    if len(q1words) == 0 or len(q2words) == 0:
        # The computer-generated chaff includes a few questions that are nothing but stopwords
        return 0
    
    shared_weights = [weights.get(w, 0) for w in q1words.keys() if w in q2words] + [weights.get(w, 0) for w in q2words.keys() if w in q1words]
    total_weights = [weights.get(w, 0) for w in q1words] + [weights.get(w, 0) for w in q2words]
    
    R = np.sum(shared_weights) / np.sum(total_weights)
    return R

# %%
plt.figure(figsize=(15, 5))
tfidf_train_word_match = df_train.apply(tfidf_word_match_share, axis=1, raw=True)
plt.hist(tfidf_train_word_match[df_train['is_duplicate'] == 0].fillna(0), bins=20, normed=True, label='Not Duplicate')
plt.hist(tfidf_train_word_match[df_train['is_duplicate'] == 1].fillna(0), bins=20, normed=True, alpha=0.7, label='Duplicate')
plt.legend()
plt.title('Label distribution over tfidf_word_match_share', fontsize=15)
plt.xlabel('word_match_share', fontsize=15)
# Out:
# /Users/galphen/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:17: RuntimeWarning: divide by zero encountered in long_scalars
# /Users/galphen/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:17: RuntimeWarning: invalid value encountered in double_scalars

# %%
from sklearn.metrics import roc_auc_score
print('Original AUC:', roc_auc_score(df_train['is_duplicate'], train_word_match))
print('   TFIDF AUC:', roc_auc_score(df_train['is_duplicate'], tfidf_train_word_match.fillna(0)))
# Out:
# ('Original AUC:', 0.52948936054569229)
# ('   TFIDF AUC:', 0.5)

# %%
# First we create our training and testing data
x_train = pd.DataFrame()
x_test = pd.DataFrame()
x_train['word_match'] = train_word_match
x_train['tfidf_word_match'] = tfidf_train_word_match
x_test['word_match'] = df_test.apply(word_match_share, axis=1, raw=True)
x_test['tfidf_word_match'] = df_test.apply(tfidf_word_match_share, axis=1, raw=True)

y_train = df_train['is_duplicate'].values
# Out:
# /Users/galphen/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:17: RuntimeWarning: divide by zero encountered in long_scalars
# /Users/galphen/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:17: RuntimeWarning: invalid value encountered in double_scalars

# %%
pos_train = x_train[y_train == 1]
neg_train = x_train[y_train == 0]

# Now we oversample the negative class
# There is likely a much more elegant way to do this...
p = 0.165
scale = ((len(pos_train) / (len(pos_train) + len(neg_train))) / p) - 1
while scale > 1:
    neg_train = pd.concat([neg_train, neg_train])
    scale -=1
neg_train = pd.concat([neg_train, neg_train[:int(scale * len(neg_train))]])
print(len(pos_train) / (len(pos_train) + len(neg_train)))

x_train = pd.concat([pos_train, neg_train])
y_train = (np.zeros(len(pos_train)) + 1).tolist() + np.zeros(len(neg_train)).tolist()
del pos_train, neg_train
# Out:
# 0

# %%
# Finally, we split some of the data off for validation
from sklearn.cross_validation import train_test_split

x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.2, random_state=4242)
# Out:
# /Users/galphen/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# xgboost install
# http://stackoverflow.com/questions/36292484/xgboost-installation-issue-with-anaconda
#
# conda install -c https://conda.anaconda.org/akode xgboost

# %%
import xgboost as xgb

# Set our parameters for xgboost
params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'logloss'
params['eta'] = 0.02
params['max_depth'] = 4

d_train = xgb.DMatrix(x_train, label=y_train)
d_valid = xgb.DMatrix(x_valid, label=y_valid)

watchlist = [(d_train, 'train'), (d_valid, 'valid')]

bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=50, verbose_eval=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-675a9320eece> in <module>()
#      13 watchlist = [(d_train, 'train'), (d_valid, 'valid')]
#      14
# ---> 15 bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=50, verbose_eval=10)
#
# TypeError: train() got an unexpected keyword argument 'verbose_eval'

# %%
# Set our parameters for xgboost
params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'logloss'
params['eta'] = 0.02
params['max_depth'] = 4

d_train = xgb.DMatrix(x_train, label=y_train)
d_valid = xgb.DMatrix(x_valid, label=y_valid)

watchlist = [(d_train, 'train'), (d_valid, 'valid')]

bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=50)
# Out:
# Will train until valid error hasn't decreased in 50 rounds.
# [0]	train-logloss:0.691766	valid-logloss:0.691673
# [1]	train-logloss:0.690655	valid-logloss:0.690361
# [2]	train-logloss:0.689455	valid-logloss:0.689240
# [3]	train-logloss:0.687955	valid-logloss:0.688057
# [4]	train-logloss:0.686735	valid-logloss:0.686913
# [5]	train-logloss:0.685739	valid-logloss:0.685949
# [6]	train-logloss:0.684527	valid-logloss:0.684840
# [7]	train-logloss:0.684042	valid-logloss:0.683694
# [8]	train-logloss:0.683235	valid-logloss:0.682695
# [9]	train-logloss:0.681280	valid-logloss:0.681900
# [10]	train-logloss:0.680315	valid-logloss:0.681054
# [11]	train-logloss:0.679539	valid-logloss:0.680171
# [12]	train-logloss:0.678598	valid-logloss:0.679418
# [13]	train-logloss:0.678176	valid-logloss:0.678487
# [14]	train-logloss:0.677207	valid-logloss:0.677692
# [15]	train-logloss:0.677259	valid-logloss:0.676961
# [16]	train-logloss:0.676370	valid-logloss:0.676370
# [17]	train-logloss:0.675977	valid-logloss:0.675543
# [18]	train-logloss:0.675098	valid-logloss:0.674984
# [19]	train-logloss:0.674128	valid-logloss:0.674191
# [20]	train-logloss:0.673272	valid-logloss:0.673724
# [21]	train-logloss:0.672552	valid-logloss:0.673186
# [22]	train-logloss:0.672678	valid-logloss:0.672728
# [23]	train-logloss:0.672188	valid-logloss:0.672240
# [24]	train-logloss:0.671274	valid-logloss:0.671612
# [25]	train-logloss:0.670227	valid-logloss:0.671175
# [26]	train-logloss:0.670294	valid-logloss:0.670564
# [27]	train-logloss:0.669616	valid-logloss:0.670191
# [28]	train-logloss:0.669082	valid-logloss:0.669586
# [29]	train-logloss:0.669304	valid-logloss:0.669410
# [30]	train-logloss:0.668796	valid-logloss:0.668910
# [31]	train-logloss:0.668065	valid-logloss:0.668394
# [32]	train-logloss:0.667722	valid-logloss:0.668232
# [33]	train-logloss:0.666991	valid-logloss:0.667712
# [34]	train-logloss:0.667544	valid-logloss:0.667449
# [35]	train-logloss:0.666905	valid-logloss:0.667159
# [36]	train-logloss:0.665849	valid-logloss:0.666726
# [37]	train-logloss:0.666177	valid-logloss:0.666441
# [38]	train-logloss:0.665394	valid-logloss:0.666199
# [39]	train-logloss:0.665740	valid-logloss:0.665997
# [40]	train-logloss:0.664734	valid-logloss:0.665687
# [41]	train-logloss:0.665050	valid-logloss:0.665364
# [42]	train-logloss:0.664437	valid-logloss:0.665177
# [43]	train-logloss:0.664455	valid-logloss:0.665041
# [44]	train-logloss:0.663776	valid-logloss:0.664663
# [45]	train-logloss:0.664119	valid-logloss:0.664460
# [46]	train-logloss:0.663481	valid-logloss:0.664104
# [47]	train-logloss:0.663839	valid-logloss:0.663962
# [48]	train-logloss:0.663259	valid-logloss:0.663835
# [49]	train-logloss:0.663068	valid-logloss:0.663741
# [50]	train-logloss:0.663350	valid-logloss:0.663380
# [51]	train-logloss:0.662444	valid-logloss:0.663307
# [52]	train-logloss:0.662756	valid-logloss:0.663065
# [53]	train-logloss:0.661968	valid-logloss:0.662904
# [54]	train-logloss:0.662372	valid-logloss:0.662888
# [55]	train-logloss:0.662110	valid-logloss:0.662592
# [56]	train-logloss:0.661544	valid-logloss:0.662520
# [57]	train-logloss:0.662219	valid-logloss:0.662228
# [58]	train-logloss:0.662050	valid-logloss:0.662161
# [59]	train-logloss:0.661491	valid-logloss:0.662116
# [60]	train-logloss:0.661627	valid-logloss:0.661902
# [61]	train-logloss:0.662018	valid-logloss:0.661843
# [62]	train-logloss:0.660902	valid-logloss:0.661802
# [63]	train-logloss:0.661041	valid-logloss:0.661604
# [64]	train-logloss:0.661422	valid-logloss:0.661506
# [65]	train-logloss:0.660649	valid-logloss:0.661404
# [66]	train-logloss:0.661052	valid-logloss:0.661392
# [67]	train-logloss:0.660669	valid-logloss:0.661355
# [68]	train-logloss:0.660493	valid-logloss:0.661330
# [69]	train-logloss:0.660207	valid-logloss:0.661017
# [70]	train-logloss:0.660429	valid-logloss:0.661008
# [71]	train-logloss:0.660832	valid-logloss:0.661003
# [72]	train-logloss:0.660028	valid-logloss:0.660769
# [73]	train-logloss:0.660211	valid-logloss:0.660766
# [74]	train-logloss:0.660384	valid-logloss:0.660638
# [75]	train-logloss:0.660228	valid-logloss:0.660624
# [76]	train-logloss:0.660027	valid-logloss:0.660576
# [77]	train-logloss:0.659653	valid-logloss:0.660578
# [78]	train-logloss:0.659829	valid-logloss:0.660456
# [79]	train-logloss:0.660270	valid-logloss:0.660540
# [80]	train-logloss:0.659310	valid-logloss:0.660487
# [81]	train-logloss:0.659129	valid-logloss:0.660454
# [82]	train-logloss:0.659858	valid-logloss:0.660321
# [83]	train-logloss:0.659846	valid-logloss:0.660257
# [84]	train-logloss:0.659663	valid-logloss:0.660220
# [85]	train-logloss:0.659430	valid-logloss:0.660040
# [86]	train-logloss:0.659086	valid-logloss:0.660095
# [87]	train-logloss:0.659283	valid-logloss:0.660061
# [88]	train-logloss:0.659830	valid-logloss:0.660007
# [89]	train-logloss:0.659634	valid-logloss:0.659920
# [90]	train-logloss:0.658753	valid-logloss:0.660107
# [91]	train-logloss:0.658911	valid-logloss:0.659921
# [92]	train-logloss:0.659270	valid-logloss:0.659825
# [93]	train-logloss:0.659308	valid-logloss:0.659891
# [94]	train-logloss:0.659487	valid-logloss:0.659788
# [95]	train-logloss:0.659628	valid-logloss:0.659711
# [96]	train-logloss:0.658956	valid-logloss:0.659848
# [97]	train-logloss:0.658897	valid-logloss:0.659676
# [98]	train-logloss:0.658794	valid-logloss:0.659810
# [99]	train-logloss:0.658760	valid-logloss:0.659740
# [100]	train-logloss:0.659274	valid-logloss:0.659639
# [101]	train-logloss:0.659174	valid-logloss:0.659785
# [102]	train-logloss:0.659101	valid-logloss:0.659561
# [103]	train-logloss:0.658432	valid-logloss:0.659709
# [104]	train-logloss:0.658897	valid-logloss:0.659488
# [105]	train-logloss:0.658797	valid-logloss:0.659636
# [106]	train-logloss:0.658745	valid-logloss:0.659495
# [107]	train-logloss:0.658806	valid-logloss:0.659654
# [108]	train-logloss:0.658975	valid-logloss:0.659513
# [109]	train-logloss:0.659153	valid-logloss:0.659518
# [110]	train-logloss:0.659323	valid-logloss:0.659375
# [111]	train-logloss:0.658433	valid-logloss:0.659526
# [112]	train-logloss:0.658404	valid-logloss:0.659477
# [113]	train-logloss:0.658250	valid-logloss:0.659485
# [114]	train-logloss:0.658754	valid-logloss:0.659351
# [115]	train-logloss:0.658812	valid-logloss:0.659498
# [116]	train-logloss:0.659022	valid-logloss:0.659450
# [117]	train-logloss:0.658976	valid-logloss:0.659331
# [118]	train-logloss:0.658651	valid-logloss:0.659466
# [119]	train-logloss:0.658790	valid-logloss:0.659280
# [120]	train-logloss:0.658443	valid-logloss:0.659382
# [121]	train-logloss:0.658487	valid-logloss:0.659475
# [122]	train-logloss:0.658618	valid-logloss:0.659259
# [123]	train-logloss:0.658303	valid-logloss:0.659434
# [124]	train-logloss:0.658298	valid-logloss:0.659410
# [125]	train-logloss:0.658469	valid-logloss:0.659275
# [126]	train-logloss:0.658534	valid-logloss:0.659456
# [127]	train-logloss:0.658984	valid-logloss:0.659181
# [128]	train-logloss:0.659033	valid-logloss:0.659295
# [129]	train-logloss:0.658885	valid-logloss:0.659331
# [130]	train-logloss:0.658930	valid-logloss:0.659431
# [131]	train-logloss:0.658826	valid-logloss:0.659162
# [132]	train-logloss:0.657948	valid-logloss:0.659358
# [133]	train-logloss:0.658161	valid-logloss:0.659323
# [134]	train-logloss:0.658130	valid-logloss:0.659265
# [135]	train-logloss:0.658672	valid-logloss:0.659212
# [136]	train-logloss:0.658363	valid-logloss:0.659410
# [137]	train-logloss:0.658576	valid-logloss:0.659374
# [138]	train-logloss:0.658473	valid-logloss:0.659105
# [139]	train-logloss:0.658542	valid-logloss:0.659303
# [140]	train-logloss:0.658530	valid-logloss:0.659252
# [141]	train-logloss:0.658490	valid-logloss:0.659163
# [142]	train-logloss:0.658700	valid-logloss:0.659111
# [143]	train-logloss:0.658390	valid-logloss:0.659309
# [144]	train-logloss:0.658405	valid-logloss:0.659366
# [145]	train-logloss:0.658947	valid-logloss:0.659316
# [146]	train-logloss:0.658907	valid-logloss:0.659224
# [147]	train-logloss:0.659118	valid-logloss:0.659176
# [148]	train-logloss:0.658185	valid-logloss:0.659235
# [149]	train-logloss:0.658220	valid-logloss:0.659292
# [150]	train-logloss:0.658137	valid-logloss:0.659106
# [151]	train-logloss:0.658127	valid-logloss:0.659065
# [152]	train-logloss:0.658193	valid-logloss:0.659250
# [153]	train-logloss:0.658035	valid-logloss:0.659245
# [154]	train-logloss:0.658031	valid-logloss:0.659226
# [155]	train-logloss:0.657989	valid-logloss:0.659127
# [156]	train-logloss:0.658553	valid-logloss:0.659167
# [157]	train-logloss:0.658543	valid-logloss:0.659121
# [158]	train-logloss:0.658600	valid-logloss:0.659271
# [159]	train-logloss:0.658615	valid-logloss:0.659331
# [160]	train-logloss:0.658812	valid-logloss:0.659229
# [161]	train-logloss:0.658733	valid-logloss:0.659060
# [162]	train-logloss:0.658785	valid-logloss:0.659191
# [163]	train-logloss:0.658774	valid-logloss:0.659142
# [164]	train-logloss:0.658412	valid-logloss:0.659211
# [165]	train-logloss:0.658463	valid-logloss:0.659337
# [166]	train-logloss:0.658457	valid-logloss:0.659310
# [167]	train-logloss:0.658581	valid-logloss:0.659068
# [168]	train-logloss:0.658593	valid-logloss:0.659114
# [169]	train-logloss:0.658628	valid-logloss:0.659173
# [170]	train-logloss:0.658626	valid-logloss:0.659165
# [171]	train-logloss:0.657697	valid-logloss:0.659235
# [172]	train-logloss:0.658248	valid-logloss:0.659221
# [173]	train-logloss:0.658241	valid-logloss:0.659192
# [174]	train-logloss:0.658291	valid-logloss:0.659310
# [175]	train-logloss:0.658212	valid-logloss:0.659145
# [176]	train-logloss:0.658431	valid-logloss:0.659133
# [177]	train-logloss:0.658411	valid-logloss:0.659052
# [178]	train-logloss:0.658423	valid-logloss:0.659100
# [179]	train-logloss:0.658103	valid-logloss:0.659255
# [180]	train-logloss:0.658111	valid-logloss:0.659287
# [181]	train-logloss:0.658091	valid-logloss:0.659204
# [182]	train-logloss:0.658089	valid-logloss:0.659195
# [183]	train-logloss:0.658102	valid-logloss:0.659247
# [184]	train-logloss:0.658064	valid-logloss:0.659166
# [185]	train-logloss:0.658062	valid-logloss:0.659156
# [186]	train-logloss:0.658057	valid-logloss:0.659132
# [187]	train-logloss:0.658272	valid-logloss:0.659108
# [188]	train-logloss:0.658276	valid-logloss:0.659121
# [189]	train-logloss:0.658289	valid-logloss:0.659175
# [190]	train-logloss:0.658342	valid-logloss:0.659308
# [191]	train-logloss:0.658322	valid-logloss:0.659225
# [192]	train-logloss:0.658336	valid-logloss:0.659280
# [193]	train-logloss:0.658335	valid-logloss:0.659275
# [194]	train-logloss:0.658793	valid-logloss:0.659038
# [195]	train-logloss:0.658809	valid-logloss:0.659103
# [196]	train-logloss:0.658808	valid-logloss:0.659097
# [197]	train-logloss:0.658839	valid-logloss:0.659140
# [198]	train-logloss:0.658842	valid-logloss:0.659151
# [199]	train-logloss:0.658851	valid-logloss:0.659186
# [200]	train-logloss:0.658854	valid-logloss:0.659198
# [201]	train-logloss:0.658696	valid-logloss:0.659196
# [202]	train-logloss:0.658694	valid-logloss:0.659190
# [203]	train-logloss:0.658707	valid-logloss:0.659243
# [204]	train-logloss:0.658688	valid-logloss:0.659163
# [205]	train-logloss:0.658742	valid-logloss:0.659300
# [206]	train-logloss:0.658741	valid-logloss:0.659295
# [207]	train-logloss:0.658740	valid-logloss:0.659293
# [208]	train-logloss:0.658659	valid-logloss:0.659116
# [209]	train-logloss:0.658662	valid-logloss:0.659127
# [210]	train-logloss:0.658657	valid-logloss:0.659108
# [211]	train-logloss:0.658659	valid-logloss:0.659116
# [212]	train-logloss:0.658650	valid-logloss:0.659078
# [213]	train-logloss:0.658650	valid-logloss:0.659076
# [214]	train-logloss:0.658648	valid-logloss:0.659070
# [215]	train-logloss:0.658702	valid-logloss:0.659205
# [216]	train-logloss:0.657760	valid-logloss:0.659222
# [217]	train-logloss:0.657759	valid-logloss:0.659220
# [218]	train-logloss:0.657774	valid-logloss:0.659277
# [219]	train-logloss:0.657771	valid-logloss:0.659268
# [220]	train-logloss:0.657771	valid-logloss:0.659265
# [221]	train-logloss:0.657970	valid-logloss:0.659174
# [222]	train-logloss:0.657972	valid-logloss:0.659182
# [223]	train-logloss:0.657972	valid-logloss:0.659185
# [224]	train-logloss:0.657981	valid-logloss:0.659219
# [225]	train-logloss:0.657983	valid-logloss:0.659228
# [226]	train-logloss:0.657889	valid-logloss:0.658997
# [227]	train-logloss:0.657943	valid-logloss:0.659137
# [228]	train-logloss:0.657943	valid-logloss:0.659135
# [229]	train-logloss:0.657941	valid-logloss:0.659129
# [230]	train-logloss:0.657955	valid-logloss:0.659183
# [231]	train-logloss:0.657955	valid-logloss:0.659182
# [232]	train-logloss:0.657958	valid-logloss:0.659195
# [233]	train-logloss:0.657935	valid-logloss:0.659102
# [234]	train-logloss:0.658489	valid-logloss:0.659097
# [235]	train-logloss:0.658489	valid-logloss:0.659100
# [236]	train-logloss:0.658487	valid-logloss:0.659091
# [237]	train-logloss:0.658488	valid-logloss:0.659094
# [238]	train-logloss:0.658501	valid-logloss:0.659144
# [239]	train-logloss:0.658122	valid-logloss:0.659147
# [240]	train-logloss:0.658125	valid-logloss:0.659160
# [241]	train-logloss:0.658125	valid-logloss:0.659159
# [242]	train-logloss:0.658125	valid-logloss:0.659158
# [243]	train-logloss:0.658174	valid-logloss:0.659276
# [244]	train-logloss:0.658175	valid-logloss:0.659279
# [245]	train-logloss:0.658177	valid-logloss:0.659287
# [246]	train-logloss:0.658178	valid-logloss:0.659290
# [247]	train-logloss:0.658168	valid-logloss:0.659250
# [248]	train-logloss:0.658168	valid-logloss:0.659250
# [249]	train-logloss:0.658169	valid-logloss:0.659253
# [250]	train-logloss:0.658171	valid-logloss:0.659261
# [251]	train-logloss:0.658172	valid-logloss:0.659264
# [252]	train-logloss:0.658166	valid-logloss:0.659242
# [253]	train-logloss:0.658388	valid-logloss:0.659241
# [254]	train-logloss:0.658387	valid-logloss:0.659239
# [255]	train-logloss:0.658388	valid-logloss:0.659240
# [256]	train-logloss:0.658391	valid-logloss:0.659253
# [257]	train-logloss:0.658296	valid-logloss:0.659022
# [258]	train-logloss:0.658296	valid-logloss:0.659021
# [259]	train-logloss:0.658310	valid-logloss:0.659076
# [260]	train-logloss:0.658309	valid-logloss:0.659074
# [261]	train-logloss:0.658309	valid-logloss:0.659074
# [262]	train-logloss:0.658313	valid-logloss:0.659088
# [263]	train-logloss:0.658307	valid-logloss:0.659065
# [264]	train-logloss:0.658308	valid-logloss:0.659067
# [265]	train-logloss:0.658308	valid-logloss:0.659068
# [266]	train-logloss:0.658361	valid-logloss:0.659202
# [267]	train-logloss:0.658361	valid-logloss:0.659202
# [268]	train-logloss:0.658362	valid-logloss:0.659205
# [269]	train-logloss:0.658339	valid-logloss:0.659110
# [270]	train-logloss:0.658342	valid-logloss:0.659124
# [271]	train-logloss:0.658342	valid-logloss:0.659123
# [272]	train-logloss:0.658341	valid-logloss:0.659121
# [273]	train-logloss:0.658342	valid-logloss:0.659122
# [274]	train-logloss:0.658355	valid-logloss:0.659176
# [275]	train-logloss:0.658355	valid-logloss:0.659176
# [276]	train-logloss:0.658351	valid-logloss:0.659157
# Stopping. Best iteration:
# [226]	train-logloss:0.657889	valid-logloss:0.658997

# %%
d_test = xgb.DMatrix(x_test)
p_test = bst.predict(d_test)

sub = pd.DataFrame()
sub['test_id'] = df_test['test_id']
sub['is_duplicate'] = p_test
sub.to_csv('simple_xgb.csv', index=False)

# %% [markdown]
# submit result:
# https://www.youtube.com/watch?v=68l47Zu4Yxg#t=368.590173
